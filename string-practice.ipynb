# %% [markdown]
# indexing

# %%
a='data'
print(a)
# Out:
# data

# %% [markdown]
# -4 -3 -2 -1
#   d   a  t  a
#
#    0   1  2  3

# %%
print(a[2])
# Out:
# t

# %%
print(a[2]+a[3])
# Out:
# ta

# %%
print(a[-3])
# Out:
# a

# %%
print(a[-4]+a[-3])
# Out:
# da

# %%
print(a[1,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1038704187.py in <cell line: 0>()
# ----> 1 print(a[1,3])
#
# TypeError: string indices must be integers, not 'tuple'

# %%
print(a[13])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1209284234.py in <cell line: 0>()
# ----> 1 print(a[13])
#
# IndexError: string index out of range

# %%
print(a*3)
# Out:
# datadatadata

# %% [markdown]
# slicing

# %%
a='data science'
print(a)
# Out:
# data science

# %%
print(a[2:6])
# Out:
# ta s

# %%
print(a[2:])
# Out:
# ta science

# %%
print(a[ :9]) # n-1 logic
# Out:
# data scie

# %%
b='python'
print(b[-4: -2])
# Out:
# th

# %%
print(b[:-2])
# Out:
# pyth

# %%
print(b[2:-2])
# Out:
# th

# %%
print(a[ : ])
# Out:
# data science

# %%
print(a[: : -1]) #- means reverse
# Out:
# ecneics atad

# %%
print(a[: : -2])
# Out:
# enisaa

# %%
b='laddu'
print(b[: : -2])
# Out:
# udl

# %%
b='laddu'
print(b[: : 2]) # no - means no reverse
# Out:
# ldu

# %%
b='nagendhra'
print(b[8:2:-2]) #skip by 2 , & follows n-1 logic
# Out:
# ahn

# %%
print(b[7:1:-2])
# Out:
# rde

# %%
print(b[2 : 7 : -2])  # no o/p bcz left side small value slicing is not good

# %%
print(b[: : -1])
# Out:
# arhdnegan

# %% [markdown]
# mutable & immutable

# %%
f='data'
f[4] = 'j'
print(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1472241052.py in <cell line: 0>()
#       1 f='data'
# ----> 2 f[4] = 'j'
#       3 print(f)
#
# TypeError: 'str' object does not support item assignment

# %%
f='data'
del f[2]
print(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4059471466.py in <cell line: 0>()
#       1 f='data'
# ----> 2 del f[2]
#       3 print(f)
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# string built in functions

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
len(dir(str))
# Out:
# 81

# %%
a='ladDU GanjI'
a=a.capitalize()
print(a)
# Out:
# Laddu ganji

# %%
a='laddu ganji'
a=a.title()
print(a)
# Out:
# Laddu Ganji

# %%
a='LAddu gaNJI'
a=a.lower()
print(a)
# Out:
# laddu ganji

# %%
a='laddu ganji'
a=a.upper()
print(a)
# Out:
# LADDU GANJI

# %%
a='laddu ganji'
a=a.islower()
print(a)
# Out:
# True

# %%
a='laDDU Ganji'
a=a.islower()
print(a)
# Out:
# False

# %%
a='LADDU'
a=a.isupper()
print(a)
# Out:
# True

# %%
a='LAddu'
a=a.isupper()
print(a)
# Out:
# False

# %%
a='Laddu'
a=a.isalpha()
print(a)
# Out:
# True

# %%
a='LADDU'
a=a.isalpha()
print(a)
# Out:
# True

# %%
a='Laddu Ganji'
a=a.isalpha()
print(a)
# Out:
# False

# %%
a='laddu123'
a=a.isalpha()
print(a)
# Out:
# False

# %%
a='laddu@@'
a=a.isalpha()
print(a)
# Out:
# False

# %%
a='123'
a=a.isnumeric()
print(a)
# Out:
# True

# %%
a='ppp'
a=a.isnumeric()
print(a)
# Out:
# False

# %%
a='pp12'
a=a.isnumeric()
print(a)
# Out:
# False

# %%
a='-12'
a=a.isnumeric()
print(a)
# Out:
# False

# %%
a='12.76'
a=a.isnumeric()
print(a)
# Out:
# False

# %%
a='ppp'
print(a.isalnum())
# Out:
# True

# %%
a='123'
print(a.isalnum())
# Out:
# True

# %%
a='ppp123'
print(a.isalnum())
# Out:
# True

# %%
a='laddu ganji'
print(a.isalnum())
# Out:
# False

# %%
a='laddu#ganji'
print(a.isalnum())
# Out:
# False

# %%
a='python'
print(a.startswith('p'))
# Out:
# True

# %%
a='python'
print(a.startswith('o'))
# Out:
# False

# %%
a='python'
print(a.endswith('n'))
# Out:
# True

# %%
a='python'
print(a.endswith('y'))
# Out:
# False

# %%
a='data'
print(a.replace('t','p'))
# Out:
# dapa

# %%
a='data'
print(a.replace('a','p'))
# Out:
# dptp

# %%
a='data'
print(a.replace('a','p',1))
# Out:
# dpta

# %%
a='data'
print(a.index('t'))
# Out:
# 2

# %%
a='data'
print(a.index('a'))
# Out:
# 1

# %%
a='data'
print(a.index('a',2))
# Out:
# 3

# %%
a='data science uk'
s=a[ : a.index('e',9)]
e=a[a.index('e',9) : ]
r=e.replace('e','q')
print(s+r)
# Out:
# data sciencq uk

# %%
a='science'
print(a.count('e'))
# Out:
# 2

# %%
# membership function
s='i love python'
print('love' in s)
# Out:
# True

# %%
# ascii values
a='python'
b='java'
print(a>b)
# Out:
# True

# %%
# ord
print(ord('A'))
print(ord('a'))
# Out:
# 65
# 97

# %%
# chr
print(chr(65))
print(chr(97))
# Out:
# A
# a

# %%
# split
a=' i love python'
print(a.split())
# Out:
# ['i', 'love', 'python']

# %%
a='I.love.python'
print(a.split('.'))
# Out:
# ['I', 'love', 'python']

# %%
a='I.love.python'
b=a.split('.')
c=b[::-1]
print(a)
print(b)
print(c)
# Out:
# I.love.python
# ['I', 'love', 'python']
# ['python', 'love', 'I']

# %%
a='I.love.python'
print(a.split('.',1)) # one space after I
print(a.split('.',2))  #2 spaces
# Out:
# ['I', 'love.python']
# ['I', 'love', 'python']

# %%
# join
a=['python','uk']
b='_'.join(a)
print(b)
# Out:
# python_uk

# %%
a='usa uk aus afr'
print(a)

b=a.split()
print(b)

c='->'.join(b)
print(c)
# Out:
# usa uk aus afr
# ['usa', 'uk', 'aus', 'afr']
# usa->uk->aus->afr

# %%
a='aaa bbb ccc'
b='->'.join(a)
print(b)
# Out:
# a->a->a-> ->b->b->b-> ->c->c->c

# %%
a='aaa bbb ccc'
b=list(a)
print(b)
# Out:
# ['a', 'a', 'a', ' ', 'b', 'b', 'b', ' ', 'c', 'c', 'c']

# %%
a=['aaa',' bbb',' ccc']
b='_'.join(a)
print(b)
# Out:
# aaa_ bbb_ ccc

# %%
a=['aaa',' bbb',' ccc']
print(a.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1725834024.py in <cell line: 0>()
#       1 a=['aaa',' bbb',' ccc']
# ----> 2 print(a.split())
#
# AttributeError: 'list' object has no attribute 'split'
