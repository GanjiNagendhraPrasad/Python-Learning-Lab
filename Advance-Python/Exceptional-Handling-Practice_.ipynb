# %%
print'ppp')
# Out:
#   File "/tmp/ipython-input-3065437773.py", line 1
#     print'ppp')
#               ^
# SyntaxError: unmatched ')'

# %%
print(nn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3475163236.py in <cell line: 0>()
# ----> 1 print(nn)
#
# NameError: name 'nn' is not defined

# %%
a=[1,2,3]
print(a[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2446729775.py in <cell line: 0>()
#       1 a=[1,2,3]
# ----> 2 print(a[6])
#
# IndexError: list index out of range

# %%
a={'a':1,'b':2,'c':3}
print(a[5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3389031986.py in <cell line: 0>()
#       1 a={'a':1,'b':2,'c':3}
# ----> 2 print(a[5])
#
# KeyError: 5

# %%
if 5>2:
print('5')
# Out:
#   File "/tmp/ipython-input-2419815666.py", line 2
#     print('5')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a=0
b=10
print(b/a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2248970349.py in <cell line: 0>()
#       1 a=0
#       2 b=10
# ----> 3 print(b/a)
#
# ZeroDivisionError: division by zero

# %%
a=int('sam')
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-427779296.py in <cell line: 0>()
# ----> 1 a=int('sam')
#       2 a
#
# ValueError: invalid literal for int() with base 10: 'sam'

# %%
a='pp23k'
b=int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3089731280.py in <cell line: 0>()
#       1 a='pp23k'
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'pp23k'

# %%
a=0
b=100
print(b/a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-595074808.py in <cell line: 0>()
#       1 a=0
#       2 b=100
# ----> 3 print(b/a)
#
# ZeroDivisionError: division by zero

# %%
a='2'
b=int(a)
print(b)
# Out:
# 2

# %%
a=2
b=str(a)
b
# Out:
# '2'

# %%
a='pp'
b=int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4007634433.py in <cell line: 0>()
#       1 a='pp'
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'pp'

# %%
a='ppp'
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3493617098.py in <cell line: 0>()
#       1 a='ppp'
# ----> 2 print(p)
#
# NameError: name 'p' is not defined

# %%
with open('ppp.txt','r') as f:
  print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3002574872.py in <cell line: 0>()
# ----> 1 with open('ppp.txt','r') as f:
#       2   print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ppp.txt'

# %%
a=[1,2,3,4,5]
for i in a:
print(i)
# Out:
#   File "/tmp/ipython-input-541841738.py", line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
a=0
b=55
print(b/a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3373366161.py in <cell line: 0>()
#       1 a=0
#       2 b=55
# ----> 3 print(b/a)
#
# ZeroDivisionError: division by zero

# %%
try:
  a=0
  b=99
  print(b/a)
except:
  print('ppp')
# Out:
# ppp

# %%
try:
  a=0
  b=99
  print(b/a)
except Exception as e:
  print(e)
# Out:
# division by zero

# %%
try:
  a='ppp'
  print(a1)

except Exception as e:
  print(e)
# Out:
# name 'a1' is not defined

# %%
import os
import sys

try:
  a=0
  b=99
  print(b/a)
except Exception as e:
  type,msg,line=sys.exc_info()
  print(f'{type} due to {msg} in line {line.tb_lineno}')
# Out:
# <class 'ZeroDivisionError'> due to division by zero in line 7
