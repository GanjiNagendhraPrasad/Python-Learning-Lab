# %%
a={22,11,21,33,44}

print(a)

print(type(a))
# Out:
# {33, 21, 22, 11, 44}
# <class 'set'>

# %%
a={1,2,3,'ppp','123',99}
print(a)
# Out:
# {1, 2, 3, 99, '123', 'ppp'}

# %%
a=set()   # empty set
print(a)
# Out:
# set()

# %%
a={1,2.2,'ppp','123',(11,22)}  # Elements of a set are immutable
print(a)
# Out:
# {1, 2.2, '123', (11, 22), 'ppp'}

# %%
## set is mutable (changable)
# but the values inside the set should be immutable

# %%
a={1,2.2,'ppp','123',(11,22),[1,2,3]}   # list is mutable
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3590094682.py in <cell line: 0>()
# ----> 1 a={1,2.2,'ppp','123',(11,22),[1,2,3]}
#       2 print(a)
#
# TypeError: unhashable type: 'list'

# %%
#Sets are mutable
#Adding Elements to Python Set

a={1,2,3}
a.add(4)   # add will add only single value
print(a)
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3}
a.update([4,5,6])  # update will add multiple values
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={1,2,3}
a.update([4,5],['ppp'],{33,55})
print(a)
# Out:
# {1, 2, 3, 4, 5, 33, 'ppp', 55}

# %%
a={1,2,33,44,56,77,90}  # pop
a.pop()
print(a)
# Out:
# {2, 33, 56, 90, 44, 77}

# %%
a={1,2,33,44,56,77,90}  # pop
a.pop(2)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3067132071.py in <cell line: 0>()
#       1 a={1,2,33,44,56,77,90}  # pop
# ----> 2 a.pop(2)
#       3 print(a)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
a={1,2,33,44,56,77,90}    # discard
a.discard(2)
print(a)
# Out:
# {1, 33, 56, 90, 44, 77}

# %%
a={1,2,33,44,56,77,90}
a.discard(999)        # here it will be silent, no error
print(a)
# Out:
# {1, 2, 33, 56, 90, 44, 77}

# %%
a={1,2,33,44,56,77,90}  #  remove
a.remove(33)
print(a)
# Out:
# {1, 2, 56, 90, 44, 77}

# %%
a={1,2,33,44,56,77,90}
a.remove(999)       # here it will not be silent, error will come
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4196919694.py in <cell line: 0>()
#       1 a={1,2,33,44,56,77,90}
# ----> 2 a.remove(999)
#       3 print(a)
#
# KeyError: 999

# %%
#Python Set Operations
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
c=a.union(b)
print(c)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a | b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a.intersection(b))
# Out:
# {4, 5, 6}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a & b)
# Out:
# {4, 5, 6}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a-b)
print(b-a)
# Out:
# {1, 2, 3}
# {8, 7}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a.difference(b))
# Out:
# {1, 2, 3}

# %%
a={'python','c','c++','java'}
b={'sql','c++'}
print(a-b)
print(b-a)
# Out:
# {'c', 'java', 'python'}
# {'sql'}

# %%
#Python Set Symmetric Difference  #union -intersection
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a^b)   #not the common elements in both sets
# Out:
# {1, 2, 3, 7, 8}

# %%
a = {1, 2, 3, 4, 5, 6}
b = {4, 5, 6, 7, 8}
print(a.symmetric_difference(b))
# Out:
# {1, 2, 3, 7, 8}

# %%
#Python Set Membership Test

a= {1, 2, 'ppp','lol'}
print( 1 in a)
print(3 in a)
print('ppp' in a)
# Out:
# True
# False
# True

# %%
a=set([1,43,6])
a
# Out:
# {1, 6, 43}

# %%
a={1,2,3,4}
b=a
print(b)
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3}  # deep copy
b=a
print(a)
print(b)

print(id(a))
print(id(b))

a.add(99)

print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# 138772533779744
# 138772533779744
# {99, 1, 2, 3}
# {99, 1, 2, 3}

# %%
a={1,2,3}  # shallow copy
b=a.copy()
print(a)
print(b)

print(id(a))
print(id(b))

a.add(99)

print(a)
print(b)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# 138772533774592
# 138772533783552
# {99, 1, 2, 3}
# {1, 2, 3}

# %%
#Built-in Functions in Python for Set

a={1,23,65}
print(len(a))
# Out:
# 3

# %%
a={1,2,3}
print(max(a))
# Out:
# 3

# %%
a={1,2,3}
print(min(a))
# Out:
# 1

# %%
a={1,2,3}
print(sum(a))
# Out:
# 6

# %%
a={23,42,39}
print(sorted(a))
# Out:
# [23, 39, 42]

# %%
a={23,42,39}
print(sorted(a,reverse=True))
# Out:
# [42, 39, 23]

# %%
#Python isdisjoint() #if they have no common element
a = {1, 2, 3, 4, 5}
b = {6, 7, 8,}
print(a.isdisjoint(b))
# Out:
# False

# %%
a = {1, 2, 3, 4, 5}
b = {6, 7, 8,}
print(a.isdisjoint(b))
# Out:
# False

# %%
#Python difference_update()

set1 = {1, 2, 3, 4, 5, 6}
set2 = {4, 5, 6, 7, 8}
b.difference_update(a)  #Remove all elements of another set from this set.
print(b)
# Out:
# {8, 6, 7}

# %%
# intersection_update

a= {"Devansh", "bob", "castle"}
b = {"bob", "dude", "emyway"}
c = {"fuson", "bob", "castle"}    # from b and c output os bob

a.intersection_update(b,c) #Update a set with the intersection of itself and another.

print(a)
# Out:
# {'bob'}

# %%
#Python issubset()
a = {4, 5, 6}
b = {4, 5, 6, 7, 8}

print(a.issubset(b)) # is set1 subset of set2?

print(b.issubset(a)) # is set2 subset of set1?
# Out:
# True
# False

# %%
# empty set

a=set()
print(a)

b=set([1,4,2,6])
print(b)
# Out:
# set()
# {1, 2, 4, 6}

# %%
a=set()
a.add(11)
print(a)

a.update([5,4,3])
print(a)
# Out:
# {11}
# {3, 11, 4, 5}

# %%
a=set([1,2,3])
a.pop()
print(a)
a.pop()
print(a)
# Out:
# {2, 3}
# {3}
